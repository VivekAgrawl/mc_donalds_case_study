# %% [markdown]
# # Case Study: Fast Food
#
# For this case study, the objective is to conduct market segmentation analysis using a dataset originally collected to assess the validity of various survey answer formats in brand image research. The data is described in prior studies by Dolnicar and others. In this scenario, we will assume the role of McDonald's and aim to identify distinct consumer segments with varying perceptions of the brand. This analysis will help us determine which market segments to prioritize and what messages to convey.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import adjusted_rand_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from statsmodels.graphics.mosaicplot import mosaic
from itertools import product

# %% [markdown]
# # Step 2: Specifying the Ideal Target Segment
#
# ## Knock_out criteria
# * Homogenous
# * Distinct
# * Matching the strength's of McDonald's
# * Identifiable
# * Reacheable
#
# ## Attractivenss criteria
# * Positive perception of McDonald's
# * Frequently eats out
# * Likes fast food
# * Wish to learn more about market segments which are currently not fond of McDonald's

# %%
data = pd.read_csv("data/mcdonalds.csv")

# %%
data.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %% [markdown]
# # Step 4: Exploring Data

# %%
def lencoder(col):
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    return data[col]

# %%
for col in data.columns[:11]:
    data[col] = lencoder(col)

# %%
data[data.columns[:11]].mean()
# Out:
# yummy         0.552650
# convenient    0.907777
# spicy         0.093599
# fattening     0.867171
# greasy        0.526497
# fast          0.900206
# cheap         0.598761
# tasty         0.644184
# expensive     0.357880
# healthy       0.198899
# disgusting    0.242946
# dtype: float64

# %% [markdown]
# * The average values of the transformed binary numeric segmentation variables indicate that about half of the respondents (55%) perceive McDonald's as YUMMY, 91% believe that eating at McDonald's is CONVENIENT, but only 9% think that McDonald's food is SPICY

# %%
# Principal Component Analysis
pca = PCA(random_state = 42)

# %%
pca.fit(data[data.columns[:11]])
# Out:
# PCA(random_state=42)

# %%
data_pca = pca.transform(data[data.columns[:11]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.29944723, 0.19279721, 0.13304535, 0.08309578, 0.05948052,
#        0.05029956, 0.0438491 , 0.03954779, 0.0367609 , 0.03235329,
#        0.02932326])

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.29944723, 0.49224445, 0.6252898 , 0.70838558, 0.7678661 ,
#        0.81816566, 0.86201476, 0.90156255, 0.93832345, 0.97067674,
#        1.        ])

# %%
df_pca = pd.DataFrame(data_pca, columns = [f'PC{x}' for x in range(1, 12)])

# %%
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.425367 -0.219079  0.663255 -0.401300  0.201705 -0.389767 -0.211982
# 1 -0.218638  0.388190 -0.730827 -0.094724  0.044669 -0.086596 -0.095877
# 2  0.375415  0.730435 -0.122040  0.692262  0.839643 -0.687406  0.583112
# 3 -0.172926 -0.352752 -0.843795  0.206998 -0.681415 -0.036133 -0.054284
# 4  0.187057 -0.807610  0.028537  0.548332  0.854074 -0.097305 -0.457043
#
#         PC8       PC9      PC10      PC11
# 0  0.163235  0.181007  0.515706 -0.567074
# 1 -0.034756  0.111476  0.493313 -0.500440
# 2  0.364379 -0.322288  0.061759  0.242741
# 3 -0.231477 -0.028003 -0.250678 -0.051034
# 4  0.171758 -0.074409  0.031897  0.082245

# %%
pca_summary = pd.DataFrame({'Standard Deviation':df_pca.std(),
                           'Proportion of Variance': pca.explained_variance_ratio_,
                           'Cumultive Proportion': pca.explained_variance_ratio_.cumsum()})

# %%
pca_summary
# Out:
#       Standard Deviation  Proportion of Variance  Cumultive Proportion
# PC1             0.757050                0.299447              0.299447
# PC2             0.607456                0.192797              0.492244
# PC3             0.504619                0.133045              0.625290
# PC4             0.398799                0.083096              0.708386
# PC5             0.337405                0.059481              0.767866
# PC6             0.310275                0.050300              0.818166
# PC7             0.289697                0.043849              0.862015
# PC8             0.275122                0.039548              0.901563
# PC9             0.265251                0.036761              0.938323
# PC10            0.248842                0.032353              0.970677
# PC11            0.236903                0.029323              1.000000

# %% [markdown]
#  From Principal Components Analysis indicate that the first two components capture about 50% of the information contained in the segmentation variables.

# %%
# Factor Loadings
factor_loadings = pd.DataFrame(pca.components_, index = data.columns[:11], columns = df_pca.columns)

# %%
factor_loadings.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_e2f1b_row0_col0, #T_e2f1b_row1_col6, #T_e2f1b_row2_col4, #T_e2f1b_row4_col10, #T_e2f1b_row5_col2, #T_e2f1b_row5_col3, #T_e2f1b_row6_col9, #T_e2f1b_row7_col5, #T_e2f1b_row8_col7, #T_e2f1b_row9_col1, #T_e2f1b_row10_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e2f1b_row0_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_e2f1b_row0_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_e2f1b_row0_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_e2f1b_row0_col4 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_e2f1b_row0_col5 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_e2f1b_row0_col6, #T_e2f1b_row9_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_e2f1b_row0_col7, #T_e2f1b_row2_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_e2f1b_row0_col8 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_e2f1b_row0_col9 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_e2f1b_row0_col10, #T_e2f1b_row1_col8, #T_e2f1b_row3_col9, #T_e2f1b_row4_col1, #T_e2f1b_row4_col4, #T_e2f1b_row6_col2, #T_e2f1b_row6_col7, #T_e2f1b_row7_col3, #T_e2f1b_row8_col0, #T_e2f1b_row9_col6, #T_e2f1b_row10_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e2f1b_row1_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_e2f1b_row1_col1, #T_e2f1b_row7_col6 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_e2f1b_row1_col2, #T_e2f1b_row2_col7 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_e2f1b_row1_col3 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_e2f1b_row1_col4, #T_e2f1b_row6_col10 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_e2f1b_row1_col5, #T_e2f1b_row5_col7, #T_e2f1b_row6_col5 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_e2f1b_row1_col7 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_e2f1b_row1_col9, #T_e2f1b_row6_col8 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_e2f1b_row1_col10 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_e2f1b_row2_col1, #T_e2f1b_row3_col7 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_e2f1b_row2_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_e2f1b_row2_col3 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_e2f1b_row2_col5, #T_e2f1b_row7_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_e2f1b_row2_col6 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_e2f1b_row2_col8, #T_e2f1b_row5_col10, #T_e2f1b_row7_col9 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_e2f1b_row2_col9 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_e2f1b_row2_col10 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col1 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_e2f1b_row3_col4 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col5, #T_e2f1b_row6_col6 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col6 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col8, #T_e2f1b_row7_col10, #T_e2f1b_row8_col8 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_e2f1b_row3_col10 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_e2f1b_row4_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_e2f1b_row4_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_e2f1b_row4_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_e2f1b_row4_col5 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_e2f1b_row4_col6 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_e2f1b_row4_col7 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_e2f1b_row4_col8 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_e2f1b_row4_col9, #T_e2f1b_row7_col4 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_e2f1b_row5_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_e2f1b_row5_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_e2f1b_row5_col4 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_e2f1b_row5_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e2f1b_row5_col6 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_e2f1b_row5_col8 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_e2f1b_row5_col9 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_e2f1b_row6_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_e2f1b_row6_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_e2f1b_row6_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_e2f1b_row6_col4 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_e2f1b_row7_col0, #T_e2f1b_row10_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_e2f1b_row7_col2, #T_e2f1b_row10_col4 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_e2f1b_row7_col7 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_e2f1b_row7_col8 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_e2f1b_row8_col1, #T_e2f1b_row8_col4 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_e2f1b_row8_col2 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_e2f1b_row8_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_e2f1b_row8_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_e2f1b_row8_col6 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_e2f1b_row8_col9 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_e2f1b_row8_col10 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_e2f1b_row9_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_e2f1b_row9_col3 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_e2f1b_row9_col4 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_e2f1b_row9_col5 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_e2f1b_row9_col7 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_e2f1b_row9_col8 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_e2f1b_row9_col9 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_e2f1b_row9_col10 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_e2f1b_row10_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_e2f1b_row10_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_e2f1b_row10_col3, #T_e2f1b_row10_col7 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_e2f1b_row10_col6 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_e2f1b_row10_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_e2f1b_row10_col10 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e2f1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2f1b_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_e2f1b_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_e2f1b_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_e2f1b_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_e2f1b_level0_col4" class="col_heading level0 col4" >PC5</th>
#       <th id="T_e2f1b_level0_col5" class="col_heading level0 col5" >PC6</th>
#       <th id="T_e2f1b_level0_col6" class="col_heading level0 col6" >PC7</th>
#       <th id="T_e2f1b_level0_col7" class="col_heading level0 col7" >PC8</th>
#       <th id="T_e2f1b_level0_col8" class="col_heading level0 col8" >PC9</th>
#       <th id="T_e2f1b_level0_col9" class="col_heading level0 col9" >PC10</th>
#       <th id="T_e2f1b_level0_col10" class="col_heading level0 col10" >PC11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2f1b_level0_row0" class="row_heading level0 row0" >yummy</th>
#       <td id="T_e2f1b_row0_col0" class="data row0 col0" >-0.476933</td>
#       <td id="T_e2f1b_row0_col1" class="data row0 col1" >-0.155332</td>
#       <td id="T_e2f1b_row0_col2" class="data row0 col2" >-0.006356</td>
#       <td id="T_e2f1b_row0_col3" class="data row0 col3" >0.116232</td>
#       <td id="T_e2f1b_row0_col4" class="data row0 col4" >0.304443</td>
#       <td id="T_e2f1b_row0_col5" class="data row0 col5" >-0.108

# %%
# Calculate centroid
index_names = factor_loadings.index

# Plot data points
sns.scatterplot(df_pca, x = 'PC1', y = 'PC2', color = 'grey')

# Plot arrows from centroid to provided coordinates with index names
for i in range(len(factor_loadings['PC1'])):
    plt.arrow(0, 0, factor_loadings['PC1'][i] * 1.5, factor_loadings['PC2'][i] * 1.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
    plt.text(factor_loadings['PC1'][i] * 1.5, factor_loadings['PC2'][i]* 1.5, index_names[i], fontsize=12, ha='right', color = 'red')

# Set labels and legend
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('A Principal components analysis of the fast food data set')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 5: Extracting Segments

# %%
data_km28 = [KMeans(n_clusters = k, random_state = 42).fit(data[data.columns[:11]]) for k in range(2, 9)]

# %%
wcss = [model.inertia_ for model in data_km28]

# %%
fig = plt.figure(figsize = (6,4))
sns.barplot(x = list(range(2, 9)), y = wcss, color = 'grey')
sns.lineplot(x = list(range(0, 7)), y = wcss, color = 'red', marker = 'o')
plt.arrow(3, 2000, -1, -400)
plt.text(3, 2000, 'Elbow')
plt.xlabel("Number of Segments")
plt.ylabel('Sum of Within Cluster Distances')
plt.title("Scree plot for the fast food data set")
plt.show()

# %%
kmeans = data_km28[2]

# %%
data_clust = data.copy()
data_clust['cluster'] = kmeans.labels_

# %%
data_clust.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting Like  Age      VisitFrequency  Gender  cluster
# 0        0           0   -3   61  Every three months  Female        2
# 1        0           0   +2   51  Every three months  Female        3
# 2        1           0   +1   62  Every three months  Female        3
# 3        0           1   +4   69         Once a week  Female        1
# 4        1           0   +2   49        Once a month    Male        2

# %% [markdown]
# # Step 6: Profiling Segments

# %%
columns_segment = ['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap','tasty', 'expensive', 'healthy', 'disgusting', 'cluster']
data_pivot = data_clust[columns_segment].groupby('cluster').sum().T
data_pivot_percentage = data_pivot.copy()
for i in range(4):
    data_pivot_percentage[i] = data_pivot_percentage[i]/data_clust['cluster'].value_counts()[i]

# %%
data_pivot_mean = data_pivot_percentage.mean(axis = 1).reset_index()
data_pivot_mean.columns = ['Variable', 'Value']

# %%
# Segment Profile Plot
plt.figure(figsize = (12, 12))
for i in range(4):
    plt.subplot(2, 2, i+1)
    sns.barplot(data_pivot_percentage, x = i, y = data_pivot_percentage.index)
    sns.scatterplot(data_pivot_mean, x = 'Value', y = 'Variable', color = 'red')
    for index, row in data_pivot_mean.iterrows():
        plt.hlines(y=row['Variable'], xmin=0, xmax=row['Value'], colors='red', alpha = 0.2)
    plt.ylabel("")
    plt.xlabel("")
    plt.title(f"Cluster {i}: {data_clust['cluster'].value_counts()[i]} ({data_clust['cluster'].value_counts()[i]*100/len(data_clust):.0f}%)")
plt.suptitle("Segment profile plot for the four-segment solution for the fast food data set", fontsize = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Cluster 0 thinks McDonald's is expensive and disgusting
# * Cluster 1 views McDonald's as yummy, cheap, tasty and healthy
# * Members of cluster 2 share the view that McDonald's is cheap, but also think that the food served at McDonald's is greasy and disgusting.
# * Finally, cluster 3 members of this cluster believe that McDonald's food id expensive, yummy and tasty.

# %%
data_pca = df_pca.copy()
data_pca['cluster'] = kmeans.labels_

# %%
# Calculate centroid
index_names = factor_loadings.index

# Plot data points
sns.scatterplot(data_pca, x = 'PC1', y = 'PC2', hue = 'cluster', palette = 'viridis')

# Plot arrows from centroid to provided coordinates with index names
for i in range(len(factor_loadings['PC1'])):
    plt.arrow(0, 0, factor_loadings['PC1'][i] * 1.5, factor_loadings['PC2'][i] * 1.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
    plt.text(factor_loadings['PC1'][i] * 1.5, factor_loadings['PC2'][i]* 1.5, index_names[i], fontsize=12, ha='right', color = 'red')

# Set labels and legend
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Segment separation plot using principal components 1 and 2')
plt.grid(True)
plt.show()

# %% [markdown]
# # Step 7 Describing Segments

# %%
# Number of cluster along the x-axis and loving or hating McDonald's along the y-axis
fig = plt.figure(figsize = (8, 8))
ax = fig.gca()
mosaic(data_clust, ['cluster', 'Like'], ax= ax);

# %%
# Gender distribution across cluster
fig = plt.figure(figsize = (5, 4))
ax = fig.gca()
mosaic(data_clust, ['cluster', 'Gender'], ax = ax);

# %%
# Number of cluster along the x-axis and age along the y-axis
plt.figure(figsize = (5,4))
sns.boxplot(data_clust, x= 'cluster', y = 'Age', palette = 'viridis', width = 0.7)
plt.xlabel("segment number")
plt.ylabel("age")
plt.title("Parallel box and whisker plot of age by segment")
plt.show()

# %% [markdown]
# # Step 8 Selecting the Target Segments

# %%
data_segment = data_clust[data_clust.columns[-5:]]

# %%
mask_like = {'I hate it!-5': -5, '-4': -4, '-3': -3, '-2': -2, '-1': -1, '0': 0, '+1': 1, '+2': 2, '+3': 3, '+4': 4, 'I love it!+5': 5}
mask_gender = {'Female':0, 'Male':1}
mask_VisitFrequency = {'Never': 0, 'Once a year':1, 'Every three months':2, 'Once a month':3, 'Once a week': 4, 'More than once a week': 5}

# %%
data_segment['Like'] = data_segment['Like'].map(mask_like)
data_segment['Gender'] = data_segment['Gender'].map(mask_gender)
data_segment['VisitFrequency'] = data_segment['VisitFrequency'].map(mask_VisitFrequency)

# %%
data_segment_mean = data_segment.groupby('cluster').mean().reset_index()

# %%
plt.figure(figsize = (5, 4))
size = data_segment_mean['Gender'] * 500
sns.scatterplot(data_segment_mean, x = 'VisitFrequency', y = 'Like', s=size, hue = 'cluster', palette = 'viridis')
plt.xlim(1, 4)
plt.ylim(-3, 3)
plt.title("Segment Evaluation Plot")
plt.show()

# %% [markdown]
# Above figure represents a simplified segment evaluation plot. Market segments 1 and 3 are located in the attractive quadrant of the segment evaluation plot. Members of these two segments like McDonald's and visit it frequently. These segments need to be retained, and their needs must be satisfied in the future. Market segment 0 is located in the least attractive position. Members of this segment hate McDonald's and rarely eat there, making them unattractive as a potential market segment.
